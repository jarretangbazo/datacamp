# %% [markdown]
# # Investigating Netflix Movies
# I work for a production company that specializes in nostalgic styles and want to do some research on movies released in the 1990's. I'll perform exploratory data analysis on Netflix data to better understand movies from this decade.
#
# ### Visualize
# - Build a word cloud from the movie and TV shows descriptions. Make sure to remove stop words!
#
# ### Analyze
# - Has Netflix invested more in certain genres (see listed_in) in recent years? What about certain age groups (see ratings)?

# %%
# Import Pandas and Matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# Import data
nf = pd.read_csv("data/netflix_titles.csv", index_col = 0)
nf.head(10)
# Out:
#             type                             title  \
# show_id
# s1         Movie              Dick Johnson Is Dead
# s2       TV Show                     Blood & Water
# s3       TV Show                         Ganglands
# s4       TV Show             Jailbirds New Orleans
# s5       TV Show                      Kota Factory
# s6       TV Show                     Midnight Mass
# s7         Movie  My Little Pony: A New Generation
# s8         Movie                           Sankofa
# s9       TV Show     The Great British Baking Show
# s10        Movie                      The Starling
#
#                               director  \
# show_id
# s1                     Kirsten Johnson
# s2                                 NaN
# s3                     Julien Leclercq
# s4                                 NaN
# s5                                 NaN
# s6                       Mike Flanagan
# s7       Robert Cullen, José Luis Ucha
# s8                        Haile Gerima
# s9                     Andy Devonshire
# s10                     Theodore Melfi
#
#                                                       cast  \
# show_id
# s1                                                     NaN
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# s4                                                     NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# s6       Kate Siegel, Zach Gilford, Hamish Linklater, H...
# s7       Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# s8       Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# s9       Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# s10      Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
#
#                                                    country  \
# show_id
# s1                                           United States
# s2                                            South Africa
# s3                                                     NaN
# s4                                                     NaN
# s5                                                   India
# s6                                                     NaN
# s7                                                     NaN
# s8       United States, Ghana, Burkina Faso, United Kin...
# s9                                          United Kingdom
# s10                                          United States
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# s2       September 24, 2021          2021  TV-MA  2 Seasons
# s3       September 24, 2021          2021  TV-MA   1 Season
# s4       September 24, 2021          2021  TV-MA   1 Season
# s5       September 24, 2021          2021  TV-MA  2 Seasons
# s6       September 24, 2021          2021  TV-MA   1 Season
# s7       September 24, 2021          2021     PG     91 min
# s8       September 24, 2021          1993  TV-MA    125 min
# s9       September 24, 2021          2021  TV-14  9 Seasons
# s10      September 24, 2021          2021  PG-13    104 min
#
#                                                  listed_in  \
# show_id
# s1                                           Documentaries
# s2         International TV Shows, TV Dramas, TV Mysteries
# s3       Crime TV Shows, International TV Shows, TV Act...
# s4                                  Docuseries, Reality TV
# s5       International TV Shows, Romantic TV Shows, TV ...
# s6                      TV Dramas, TV Horror, TV Mysteries
# s7                                Children & Family Movies
# s8        Dramas, Independent Movies, International Movies
# s9                            British TV Shows, Reality TV
# s10                                       Comedies, Dramas
#
#                                                description
# show_id
# s1       As her father nears the end of his life, filmm...
# s2       After crossing paths at a party, a Cape Town t...
# s3       To protect his family from a powerful drug lor...
# s4       Feuds, flirtations and toilet talk go down amo...
# s5       In a city of coaching centers known to train I...
# s6       The arrival of a charismatic young priest brin...
# s7       Equestria's divided. But a bright-eyed hero be...
# s8       On a photo shoot in Ghana, an American model s...
# s9       A talented batch of amateur bakers face off in...
# s10      A woman adjusting to life after a loss contend...

# %% [markdown]
# ## Explore
# - What was the most frequent movie duration in the 1990s? Save an approximate answer as an integer called 'duration' (using the 1990's as the decade's start year)
# - Count the number of **short action movies** (duration less than 90 minutes) and save this as an integer 'short_movie_count'.
# - How much variety exists in Netflix's offering? Base this on three variables: type, country, and listed_in.

# %%
# Explore

# Subset dataframe to only movies from the 1990s
nf_90s_movies = nf[(nf['type'] == 'Movie') & (nf['release_year'] >= 1990) & (nf['release_year'] <= 1999)]
nf_90s_movies.head(10)

# Find the most frequent movie duration
# Out:
#           type                     title                      director  \
# show_id
# s8       Movie                   Sankofa                  Haile Gerima
# s23      Movie           Avvai Shanmughi                K.S. Ravikumar
# s25      Movie                     Jeans                    S. Shankar
# s27      Movie            Minsara Kanavu                   Rajiv Menon
# s115     Movie                    Anjaam                  Rahul Rawail
# s135     Movie  Clear and Present Danger                 Phillip Noyce
# s136     Movie               Cliffhanger                  Renny Harlin
# s145     Movie               House Party               Reginald Hudlin
# s146     Movie             House Party 2  George Jackson, Doug McHenry
# s147     Movie             House Party 3                     Eric Meza
#
#                                                       cast  \
# show_id
# s8       Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# s23      Kamal Hassan, Meena, Gemini Ganesan, Heera Raj...
# s25      Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# s27      Arvind Swamy, Kajol, Prabhu Deva, Nassar, S.P....
# s115     Madhuri Dixit, Shah Rukh Khan, Tinnu Anand, Jo...
# s135     Harrison Ford, Willem Dafoe, Anne Archer, Joaq...
# s136     Sylvester Stallone, John Lithgow, Michael Rook...
# s145     Christopher Reid, Christopher Martin, Robin Ha...
# s146     Christopher Reid, Christopher Martin, Martin L...
# s147     Christopher Reid, Christopher Martin, Tisha Ca...
#
#                                                    country  \
# show_id
# s8       United States, Ghana, Burkina Faso, United Kin...
# s23                                                    NaN
# s25                                                  India
# s27                                                    NaN
# s115                                                 India
# s135                                 United States, Mexico
# s136                   United States, Italy, France, Japan
# s145                                         United States
# s146                                         United States
# s147                                         United States
#
#                  date_added  release_year rating duration  \
# show_id
# s8       September 24, 2021          1993  TV-MA  125 min
# s23      September 21, 2021          1996  TV-PG  161 min
# s25      September 21, 2021          1998  TV-14  166 min
# s27      September 21, 2021          1997  TV-PG  147 min
# s115      September 2, 2021          1994  TV-14  143 min
# s135      September 1, 2021          1994  PG-13  142 min
# s136      September 1, 2021          1993      R  113 min
# s145      September 1, 2021          1990      R  104 min
# s146      September 1, 2021          1991      R   94 min
# s147      September 1, 2021          1994      R   94 min
#
#                                                 listed_in  \
# show_id
# s8       Dramas, Independent Movies, International Movies
# s23                        Comedies, International Movies
# s25       Comedies, International Movies, Romantic Movies
# s27      Comedies, International Movies, Music & Musicals
# s115              Dramas, International Movies, Thrillers
# s135                           Action & Adventure, Dramas
# s136                                   Action & Adventure
# s145                                Comedies, Cult Movies
# s146              Comedies, Cult Movies, Music & Musicals
# s147                           Comedies, Music & Musicals
#
#                                                description
# show_id
# s8       On a photo shoot in Ghana, an American model s...
# s23      Newly divorced and denied visitation rights wi...
# s25      When the father of the man she loves insists t...
# s27      A tangled love triangle ensues when a man fall...
# s115     A wealthy industrialist’s dangerous obsession ...
# s135     When the president's friend is murdered, CIA D...
# s136     Ranger Gabe Walker and his partner are called ...
# s145     Grounded by his strict father, Kid risks life ...
# s146     Kid goes off to college with scholarship money...
# s147     After Kid gets engaged, Play plans to throw th...

# %%
# Most frequent movie duration

## Remove 'min' from movie duration and convert minutes to numeric type
nf_movies_90s = nf_movies_90s.copy() # Need to create a separate and independent copy of nf_movies_90s in order to create this new column 'duration_MIN'
nf_movies_90s['duration_mins'] = nf_movies_90s['duration'].str.replace(' min', '', regex=False).astype(int)
duration_MODE = nf_movies_90s['duration_mins'].mode()
# nf_movies_90s.head(10)
print("The most frequent movie duration is: " + str(duration_MODE))
# Out:
# The most frequent movie duration is: 0    94
# Name: duration_mins, dtype: int64

# %%
import numpy as np

# Count of short action movies
nf_movies_90s = nf_movies_90s.copy() # Need to create a copy when adding a column to our existing dataframe
nf_movies_90s['genre_list'] = nf_movies_90s['listed_in'].str.split(', ')
#[(nf_movies_90s['duration_mins']) < 90]
nf_movies_90s.head(10)
all_genres = set([genre for sublist in nf_movies_90s['genre_list'] for genre in sublist])
# print(all_genres)


short_action_movies = nf_movies_90s[nf_movies_90s['genre_list'].apply(lambda genres: 'Action & Adventure' in genres)]
short_movie_count = len(short_action_movies[short_action_movies['duration_mins'] < 90])


# short_movie_count = short_action_movies.count()
# print(short_movie_count)
print("Number of short Action & Adventure movies: " + str(short_movie_count))
# Out:
# Number of short Action & Adventure movies: 10

# %%
# Explore
# Out:
# Object `np.mode` not found.

# %%
# Visualize

# %%
# Analyze
